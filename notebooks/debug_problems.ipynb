# %%
import sys
sys.path.append('../') # Make main module visible

from bbs.problems.rover import rover_function

rover_function.main('../bbs/problems/rover/hill_map.png')
# Out:
# [0. 0. 0. 0.]
# [1. 1. 1. 1.]
# Input = [0.2652, 0.4407, 0.145, 0.5485]
# Output = 0.2392023220230498
# Input = [0.35243, 0.1524, 0.8872, 0.5619]
# Output = 2.6325625998403406
